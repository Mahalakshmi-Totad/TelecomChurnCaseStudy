# %% [markdown]
# # Telecom Churn Prediction
#
# **Authors:** Mahalakshmi Totad

# %% [markdown]
# # Problem statement
#
# In the telecom industry, customers are able to choose from multiple service providers and actively switch from one operator to another. In this highly competitive market, the telecommunications industry experiences an average of 15-25% annual churn rate. Given the fact that it costs 5-10 times more to acquire a new customer than to retain an existing one, customer retention has now become even more important than customer acquisition.
#
# For many incumbent operators, retaining high profitable customers is the number one business
# goal. To reduce customer churn, telecom companies need to predict which customers are at high risk of churn. In this project, you will analyze customer-level data of a leading telecom firm, build predictive models to identify customers at high risk of churn, and identify the main indicators of churn.
#
# Goal is *to build a machine learning model that is able to predict churning customers based on the features provided for their usage.*
#
# **Customer behaviour during churn:**
#
# Customers usually do not decide to switch to another competitor instantly, but rather over a
# period of time (this is especially applicable to high-value customers). In churn prediction, we
# assume that there are three phases of customer lifecycle :
#
# 1. <u>The ‘good’ phase:</u> In this phase, the customer is happy with the service and behaves as usual.
#
# 2. <u>The ‘action’ phase:</u> The customer experience starts to sore in this phase, for e.g. he/she gets a compelling offer from a competitor, faces unjust charges, becomes unhappy with service quality etc. In this phase, the customer usually shows different behaviour than the ‘good’ months. It is crucial to identify high-churn-risk customers in this phase, since some corrective actions can be taken at this point (such as matching the competitor’s offer/improving the service quality etc.)
#
# 3. <u>The ‘churn’ phase:</u> In this phase, the customer is said to have churned. In this case, since you are working over a four-month window, the first two months are the ‘good’ phase, the third month is the ‘action’ phase, while the fourth month (September) is the ‘churn’ phase.

# %% [markdown]
# ### Reference Notes : Models to build
# 1. Build a predictive model using PCA, this will be able to achieve one of the two goals - to predict customers who will churn.
# 2. Use any classification model, with the main objective of identifying important predictor attributes which help the business understand indicators of churn. - A good choice to identify important variables is a logistic regression model or a model from the tree family.
# 3. Understanding how to handle class imbalance in classification models might be the key to winning this competition.
#
# The solution is divided into the following sections:
# - Data understanding and exploration
# - Data cleaning
# - Data preparation
# - Model building and evaluation
# - Model Selection
# - Find Important Features
# - Conclusion

# %% [markdown]
# ## Exploratory Data Analysis & Preprocessing

# %% [markdown]
# ### 1. Data understanding and exploration
# Let's first import the required libraries and have a look at the dataset and understand the size, attribute names etc.

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
#Data Structures
import pandas as pd
import numpy as np
import re
import os

import missingno as msno

#Sklearn
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, precision_score, recall_score , accuracy_score
from imblearn.metrics import sensitivity_specificity_support
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import RocCurveDisplay
import sklearn.metrics as metrics

#Plotting
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

#Auto EDA
import sweetviz as sv

# %matplotlib inline

# %% [markdown]
# Next, we load our datasets and the data dictionary file.
#
# The **train.csv** file contains both dependent and independent features, while the **test.csv** contains only the independent variables.
#
# So, for model selection, I will create our own train/test dataset from the **train.csv** and use the model to predict the solution using the features in unseen test.csv data for submission.

# %%
data = pd.read_csv("train.csv")
unseen = pd.read_csv("test.csv")
data_dict = pd.read_csv("data_dictionary.csv")

print(data.shape)
print(unseen.shape)
print(data_dict.shape)
# Out:
# (69999, 172)
# (30000, 171)
# (36, 2)

# %% [markdown]
# "data" will be the dataset used for training and model evalutaion

# %%
data.head()
# Out:
#    id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0   0        109             0.0             0.0             0.0
# 1   1        109             0.0             0.0             0.0
# 2   2        109             0.0             0.0             0.0
# 3   3        109             0.0             0.0             0.0
# 4   4        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8   arpu_6  \
# 0            6/30/2014            7/31/2014            8/31/2014   31.277
# 1            6/30/2014            7/31/2014            8/31/2014    0.000
# 2            6/30/2014            7/31/2014            8/31/2014   60.806
# 3            6/30/2014            7/31/2014            8/31/2014  156.362
# 4            6/30/2014            7/31/2014            8/31/2014  240.708
#
#     arpu_7  ...  sachet_3g_7  sachet_3g_8  fb_user_6  fb_user_7  fb_user_8  \
# ...

# %%
data.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69999 entries, 0 to 69998
# Data columns (total 172 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    id                        int64
#  1    circle_id                 int64
#  2    loc_og_t2o_mou            float64
#  3    std_og_t2o_mou            float64
#  4    loc_ic_t2o_mou            float64
#  5    last_date_of_month_6      object
#  6    last_date_of_month_7      object
#  7    last_date_of_month_8      object
#  8    arpu_6                    float64
#  9    arpu_7                    float64
#  10   arpu_8                    float64
#  11   onnet_mou_6               float64
#  12   onnet_mou_7               float64
#  13   onnet_mou_8               float64
#  14   offnet_mou_6              float64
#  15   offnet_mou_7              float64
#  16   offnet_mou_8              float64
#  17   roam_ic_mou_6             float64
#  18   roam_ic_mou_7             float64
# ...

# %% [markdown]
# Let's also summarize the features using the df.describe method:

# %%
data.describe(include="all")
# Out:
#                   id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count   69999.000000    69999.0         69297.0         69297.0
# unique           NaN        NaN             NaN             NaN
# top              NaN        NaN             NaN             NaN
# freq             NaN        NaN             NaN             NaN
# mean    34999.000000      109.0             0.0             0.0
# std     20207.115084        0.0             0.0             0.0
# min         0.000000      109.0             0.0             0.0
# 25%     17499.500000      109.0             0.0             0.0
# 50%     34999.000000      109.0             0.0             0.0
# 75%     52498.500000      109.0             0.0             0.0
# max     69998.000000      109.0             0.0             0.0
#
#         loc_ic_t2o_mou last_date_of_month_6 last_date_of_month_7  \
# count          69297.0                69999                69600
# ...

# %%
# sweet_report = sv.analyze(data,pairwise_analysis="off")
# sweet_report.show_html('sweet_report.html')

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# ### Remove unuseful columns

# %%
data['circle_id'].unique()
# Out:
# array([109])

# %%
# Dropping columns that have only one unique values for all the leads.
df = data

# %%
columns_with_non_unique_values = []
for i in df.columns:
    if df[i].nunique() ==1:
        columns_with_non_unique_values.append(i)

# %%
columns_with_non_unique_values
# Out:
# ['circle_id',
#  'loc_og_t2o_mou',
#  'std_og_t2o_mou',
#  'loc_ic_t2o_mou',
#  'last_date_of_month_6',
#  'last_date_of_month_7',
#  'last_date_of_month_8',
#  'std_og_t2c_mou_6',
#  'std_og_t2c_mou_7',
#  'std_og_t2c_mou_8',
#  'std_ic_t2o_mou_6',
#  'std_ic_t2o_mou_7',
#  'std_ic_t2o_mou_8']

# %%
data.drop(columns_with_non_unique_values, axis = 1, inplace = True)
data.shape
# Out:
# (69999, 159)

# %% [markdown]
# ### Handling Missing data
#
# Lets analyse the missing data.

# %% [markdown]
# #### Imputation

# %%
data.shape
# Out:
# (69999, 159)

# %%
date_cols = ['date_of_last_rech_6',
             'date_of_last_rech_7',
             'date_of_last_rech_8',
             'date_of_last_rech_data_6',
             'date_of_last_rech_data_7',
             'date_of_last_rech_data_8'
            ]

cat_cols =  ['night_pck_user_6',
             'night_pck_user_7',
             'night_pck_user_8',
             'fb_user_6',
             'fb_user_7',
             'fb_user_8',
            ]

# %%
# some recharge columns have minimum value of 1 while some don't
recharge_cols = ['total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8',
                 'count_rech_2g_6', 'count_rech_2g_7', 'count_rech_2g_8', 
                 'count_rech_3g_6', 'count_rech_3g_7', 'count_rech_3g_8',
                 'max_rech_data_6', 'max_rech_data_7', 'max_rech_data_8',
                 'av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8',
                 ]

data[recharge_cols].describe(include='all')
# Out:
#        total_rech_data_6  total_rech_data_7  total_rech_data_8  \
# count       17568.000000       17865.000000       18417.000000
# mean            2.467612           2.679989           2.652441
# std             2.794610           3.073472           3.101265
# min             1.000000           1.000000           1.000000
# 25%             1.000000           1.000000           1.000000
# 50%             1.000000           2.000000           1.000000
# 75%             3.000000           3.000000           3.000000
# max            61.000000          54.000000          60.000000
#
#        count_rech_2g_6  count_rech_2g_7  count_rech_2g_8  count_rech_3g_6  \
# count     17568.000000     17865.000000     18417.000000     17568.000000
# mean          1.865323         2.056311         2.016018         0.602288
# std           2.566377         2.799916         2.728246         1.279297
# min           0.000000         0.000000         0.000000         0.000000
# ...

# %%
# It is also observed that the recharge date and the recharge value are missing together which means the customer didn't recharge
data.loc[data.total_rech_data_6.isnull() & data.date_of_last_rech_data_6.isnull(), ["total_rech_data_6", "date_of_last_rech_data_6"]].head(20)
# Out:
#     total_rech_data_6 date_of_last_rech_data_6
# 0                 NaN                      NaN
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 5                 NaN                      NaN
# 6                 NaN                      NaN
# 8                 NaN                      NaN
# 9                 NaN                      NaN
# 11                NaN                      NaN
# 12                NaN                      NaN
# 13                NaN                      NaN
# 14                NaN                      NaN
# 17                NaN                      NaN
# 18                NaN                      NaN
# 19                NaN                      NaN
# 20                NaN                      NaN
# 21                NaN                      NaN
# 22                NaN                      NaN
# 23                NaN                      NaN
# ...

# %% [markdown]
# In the recharge variables where minumum value is 1, we can impute missing values with zeroes since it means customer didn't recharge their numbere that month.

# %%
# create a list of recharge columns where we will impute missing values with zeroes
zero_impute = ['total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8',
        'av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8',
        'max_rech_data_6', 'max_rech_data_7', 'max_rech_data_8'
       ]

# %%
# impute missing values with 0
data[zero_impute] = data[zero_impute].apply(lambda x: x.fillna(0))

# %%
# now, let's make sure values are imputed correctly
print("Missing value ratio:\n")
print(data[zero_impute].isnull().sum()*100/data.shape[1])

# summary
print("\n\nSummary statistics\n")
print(data[zero_impute].describe(include='all'))
# Out:
# Missing value ratio:
#
# total_rech_data_6     0.0
# total_rech_data_7     0.0
# total_rech_data_8     0.0
# av_rech_amt_data_6    0.0
# av_rech_amt_data_7    0.0
# av_rech_amt_data_8    0.0
# max_rech_data_6       0.0
# max_rech_data_7       0.0
# max_rech_data_8       0.0
# dtype: float64
#
#
# Summary statistics
#
#        total_rech_data_6  total_rech_data_7  total_rech_data_8  \
# count       69999.000000       69999.000000       69999.000000
# mean            0.619309           0.683981           0.697867
# std             1.762010           1.943193           1.973434
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             1.000000           1.000000           1.000000
# max            61.000000          54.000000          60.000000
#
#        av_rech_amt_data_6  av_rech_amt_data_7  av_rech_amt_data_8  \
# ...

# %% [markdown]
# All min values for 'zero_impute' columns is zero. Hence we can say that imputation was successful.

# %%
# drop id and date columns
print("Shape before dropping: ", data.shape)
data = data.drop(date_cols, axis=1)
print("Shape after dropping: ", data.shape)
# Out:
# Shape before dropping:  (69999, 159)
# Shape after dropping:  (69999, 153)

# %% [markdown]
# #### Replace NaN values in categorical variables

# %% [markdown]
# We will replace missing values in the categorical values with '-1' where '-1' will be a new category.

# %%
# replace missing values with '-1' in categorical columns
data[cat_cols] = data[cat_cols].apply(lambda x: x.fillna(-1))

# %%
# missing value ratio
print("Missing value ratio:\n")
print(data[cat_cols].isnull().sum()*100/data.shape[0])
# Out:
# Missing value ratio:
#
# night_pck_user_6    0.0
# night_pck_user_7    0.0
# night_pck_user_8    0.0
# fb_user_6           0.0
# fb_user_7           0.0
# fb_user_8           0.0
# dtype: float64

# %%
data.shape
# Out:
# (69999, 153)

# %%
# Handle missing data
total = data.isnull().sum().sort_values(ascending=False)
percent = 100*(data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#                  Total    Percent
# arpu_2g_6        52431  74.902499
# count_rech_2g_6  52431  74.902499
# arpu_3g_6        52431  74.902499
# count_rech_3g_6  52431  74.902499
# count_rech_3g_7  52134  74.478207

# %% [markdown]
# Since too much missing information would make a column not really a great predictor for churn, we drop these columns and keep only the ones which have less than 30% missing data.

# %%
initial_cols = data.shape[1]

MISSING_THRESHOLD = 0.7

include_cols = list(data.apply(lambda column: True if column.isnull().sum()/data.shape[0] < MISSING_THRESHOLD else False))

drop_missing = pd.DataFrame({'features':data.columns , 'include': include_cols})
drop_missing.loc[drop_missing.include == True,:]
# Out:
#               features  include
# 0                   id     True
# 1               arpu_6     True
# 2               arpu_7     True
# 3               arpu_8     True
# 4          onnet_mou_6     True
# ..                 ...      ...
# 148                aon     True
# 149         aug_vbc_3g     True
# 150         jul_vbc_3g     True
# 151         jun_vbc_3g     True
# 152  churn_probability     True
#
# [141 rows x 2 columns]

# %%
# drop columns
data = data.loc[:, include_cols]

dropped_cols = data.shape[1] - initial_cols
print("{0} columns dropped.".format(dropped_cols))
# Out:
# -12 columns dropped.

# %%
data.shape
# Out:
# (69999, 141)

# %%
data_filtered = data
data_filtered.shape
# Out:
# (69999, 141)

# %%
total = data_filtered.isnull().sum().sort_values(ascending=False)
percent = 100*(data_filtered.isnull().sum()/data_filtered.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#                   Total   Percent
# loc_ic_mou_8       3703  5.290076
# std_ic_t2t_mou_8   3703  5.290076
# isd_og_mou_8       3703  5.290076
# std_og_t2m_mou_8   3703  5.290076
# spl_og_mou_8       3703  5.290076

# %% [markdown]
# #### Imputation using Simple Imputer

# %%
missing_data_percent = data_filtered.isnull().any()
missing_data_percent
# Out:
# id                   False
# arpu_6               False
# arpu_7               False
# arpu_8               False
# onnet_mou_6           True
#                      ...
# aon                  False
# aug_vbc_3g           False
# jul_vbc_3g           False
# jun_vbc_3g           False
# churn_probability    False
# Length: 141, dtype: bool

# %%
impute_cols = missing_data_percent[missing_data_percent.gt(0)].index
impute_cols
# Out:
# Index(['onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8', 'offnet_mou_6',
#        'offnet_mou_7', 'offnet_mou_8', 'roam_ic_mou_6', 'roam_ic_mou_7',
#        'roam_ic_mou_8', 'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8',
#        'loc_og_t2t_mou_6', 'loc_og_t2t_mou_7', 'loc_og_t2t_mou_8',
#        'loc_og_t2m_mou_6', 'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8',
#        'loc_og_t2f_mou_6', 'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8',
#        'loc_og_t2c_mou_6', 'loc_og_t2c_mou_7', 'loc_og_t2c_mou_8',
#        'loc_og_mou_6', 'loc_og_mou_7', 'loc_og_mou_8', 'std_og_t2t_mou_6',
#        'std_og_t2t_mou_7', 'std_og_t2t_mou_8', 'std_og_t2m_mou_6',
#        'std_og_t2m_mou_7', 'std_og_t2m_mou_8', 'std_og_t2f_mou_6',
#        'std_og_t2f_mou_7', 'std_og_t2f_mou_8', 'std_og_mou_6', 'std_og_mou_7',
#        'std_og_mou_8', 'isd_og_mou_6', 'isd_og_mou_7', 'isd_og_mou_8',
#        'spl_og_mou_6', 'spl_og_mou_7', 'spl_og_mou_8', 'og_others_6',
# ...

# %%
imp = SimpleImputer(strategy='constant', fill_value=0)
data_filtered[impute_cols] = imp.fit_transform(data_filtered[impute_cols])

# %%
data_filtered.shape
# Out:
# (69999, 141)

# %%
data_filtered.describe()
# Out:
#                  id        arpu_6        arpu_7        arpu_8   onnet_mou_6  \
# count  69999.000000  69999.000000  69999.000000  69999.000000  69999.000000
# mean   34999.000000    283.134365    278.185912    278.858826    127.887939
# std    20207.115084    334.213918    344.366927    351.924315    295.115497
# min        0.000000  -2258.709000  -1289.715000   -945.808000      0.000000
# 25%    17499.500000     93.581000     86.714000     84.095000      5.430000
# 50%    34999.000000    197.484000    191.588000    192.234000     30.830000
# 75%    52498.500000    370.791000    365.369500    369.909000    113.100000
# max    69998.000000  27731.088000  35145.834000  33543.624000   7376.710000
#
#         onnet_mou_7   onnet_mou_8  offnet_mou_6  offnet_mou_7  offnet_mou_8  \
# count  69999.000000  69999.000000  69999.000000  69999.000000  69999.000000
# mean     128.754731    125.943607    191.010582    189.585401    186.146273
# ...

# %% [markdown]
# #### Inference : We can see there are outliers so let's clean it up

# %% [markdown]
# ### Handling outliers
#
# The box plots of these features show there a lot of outliers. These can be capped with k-sigma method.

# %%
### Now we will determine the data type of all features remaining

# %%
types_X_train = data_filtered.dtypes #type of each feature in data: int, float, object
num_X_train = types_X_train[(types_X_train == 'int64') | (types_X_train == float)] #numerical values are either type int or float
cat_X_train = types_X_train[types_X_train == object] #categorical values are type object

# %%
#we should convert num_train to a list to make it easier to work with
numericColumns = list(num_X_train.index)
len(numericColumns)
# Out:
# 141

# %%
print(numericColumns)
# Out:
# ['id', 'arpu_6', 'arpu_7', 'arpu_8', 'onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8', 'offnet_mou_6', 'offnet_mou_7', 'offnet_mou_8', 'roam_ic_mou_6', 'roam_ic_mou_7', 'roam_ic_mou_8', 'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8', 'loc_og_t2t_mou_6', 'loc_og_t2t_mou_7', 'loc_og_t2t_mou_8', 'loc_og_t2m_mou_6', 'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8', 'loc_og_t2f_mou_6', 'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8', 'loc_og_t2c_mou_6', 'loc_og_t2c_mou_7', 'loc_og_t2c_mou_8', 'loc_og_mou_6', 'loc_og_mou_7', 'loc_og_mou_8', 'std_og_t2t_mou_6', 'std_og_t2t_mou_7', 'std_og_t2t_mou_8', 'std_og_t2m_mou_6', 'std_og_t2m_mou_7', 'std_og_t2m_mou_8', 'std_og_t2f_mou_6', 'std_og_t2f_mou_7', 'std_og_t2f_mou_8', 'std_og_mou_6', 'std_og_mou_7', 'std_og_mou_8', 'isd_og_mou_6', 'isd_og_mou_7', 'isd_og_mou_8', 'spl_og_mou_6', 'spl_og_mou_7', 'spl_og_mou_8', 'og_others_6', 'og_others_7', 'og_others_8', 'total_og_mou_6', 'total_og_mou_7', 'total_og_mou_8', 'loc_ic_t2t_mou_6', 'loc_ic_t2t_mou_7', 'loc_ic_t2t_mou
# ...

# %%
cat_X_train = types_X_train[types_X_train == object] #categorical values are type object

# %%
categoricalColumns = list(cat_X_train.index)
print(categoricalColumns)
print(len(categoricalColumns))
# Out:
# []
# 0

# %%
numericColumns.remove('id')
print(numericColumns)
# Out:
# ['arpu_6', 'arpu_7', 'arpu_8', 'onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8', 'offnet_mou_6', 'offnet_mou_7', 'offnet_mou_8', 'roam_ic_mou_6', 'roam_ic_mou_7', 'roam_ic_mou_8', 'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8', 'loc_og_t2t_mou_6', 'loc_og_t2t_mou_7', 'loc_og_t2t_mou_8', 'loc_og_t2m_mou_6', 'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8', 'loc_og_t2f_mou_6', 'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8', 'loc_og_t2c_mou_6', 'loc_og_t2c_mou_7', 'loc_og_t2c_mou_8', 'loc_og_mou_6', 'loc_og_mou_7', 'loc_og_mou_8', 'std_og_t2t_mou_6', 'std_og_t2t_mou_7', 'std_og_t2t_mou_8', 'std_og_t2m_mou_6', 'std_og_t2m_mou_7', 'std_og_t2m_mou_8', 'std_og_t2f_mou_6', 'std_og_t2f_mou_7', 'std_og_t2f_mou_8', 'std_og_mou_6', 'std_og_mou_7', 'std_og_mou_8', 'isd_og_mou_6', 'isd_og_mou_7', 'isd_og_mou_8', 'spl_og_mou_6', 'spl_og_mou_7', 'spl_og_mou_8', 'og_others_6', 'og_others_7', 'og_others_8', 'total_og_mou_6', 'total_og_mou_7', 'total_og_mou_8', 'loc_ic_t2t_mou_6', 'loc_ic_t2t_mou_7', 'loc_ic_t2t_mou_8', '
# ...

# %%
def cap_outliers(array, k=3):
    upper_limit = array.mean() + k*array.std()
    lower_limit = array.mean() - k*array.std()
    array[array<lower_limit] = lower_limit
    array[array>upper_limit] = upper_limit
    return array

# %%
data_filtered = data_filtered[numericColumns].apply(cap_outliers, axis=0)

# %%
data_filtered.shape
# Out:
# (69999, 140)

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=45)
sns.boxplot(data =data_filtered[numericColumns])
# Out:
# <Axes: >

# %%
data_filtered.shape
# Out:
# (69999, 140)

# %% [markdown]
# ## 3. Data Preparation
# Alanyse variables and derive new and useful variables

# %% [markdown]
# ### Feature Engineering and Variable Transformation : Get high-value customers

# %% [markdown]
# #### Calculate total data recharge amount

# %%
churn = data_filtered

# %%
churn.shape
# Out:
# (69999, 140)

# %%
# calculate the total data recharge amount for June and July --> number of recharges * average recharge amount
churn['total_data_rech_6'] = churn.total_rech_data_6 * churn.av_rech_amt_data_6
churn['total_data_rech_7'] = churn.total_rech_data_7 * churn.av_rech_amt_data_7

# %% [markdown]
# ### add total data recharge and total recharge to get total combined recharge amount for a month

# %%
# calculate total recharge amount for June and July --> call recharge amount + data recharge amount
churn['amt_data_6'] = churn.total_rech_amt_6 + churn.total_data_rech_6
churn['amt_data_7'] = churn.total_rech_amt_7 + churn.total_data_rech_7

# %%
# calculate average recharge done by customer in June and July
churn['av_amt_data_6_7'] = (churn.amt_data_6 + churn.amt_data_7)/2

# %%
# look at the 70th percentile recharge amount
print("Recharge amount at 70th percentile: {0}".format(churn.av_amt_data_6_7.quantile(0.7)))
# Out:
# Recharge amount at 70th percentile: 477.0

# %%
# retain only those customers who have recharged their mobiles with more than or equal to 70th percentile amount
churn_filtered = churn.loc[churn.av_amt_data_6_7 >= churn.av_amt_data_6_7.quantile(0.7), :]
churn_filtered = churn_filtered.reset_index(drop=True)
churn_filtered.shape
# Out:
# (21011, 145)

# %%
# delete variables created to filter high-value customers
churn_filtered = churn_filtered.drop(['total_data_rech_6', 'total_data_rech_7',
                                      'amt_data_6', 'amt_data_7', 'av_amt_data_6_7'], axis=1)
churn_filtered.shape
# Out:
# (21011, 140)

# %% [markdown]
# We're left with 21,011 rows after selecting the customers who have provided recharge value of more than or equal to the recharge value of the 70th percentile customer.

# %% [markdown]
# ### UniVaraite Analysis

# %% [markdown]
# #### Visulaization

# %%
plt.figure(figsize=(10,8))
sns.heatmap(pd.DataFrame(churn_filtered, columns=churn_filtered.columns).corr())
# Out:
# <Axes: >

# %%
print(len(numericColumns))
print(len(categoricalColumns))
# Out:
# 140
# 0

# %%
sl = slice(0, 75)
print(len(numericColumns[sl]))
# Out:
# 75

# %%
#List of all numeric variables

plt.figure(figsize=(20,45))

i = 1
for variables in numericColumns[sl]:
    plt.subplot(15,5,i)
    sns.distplot(churn_filtered[variables])
    i+=1
    
plt.show()

# %%
sl = slice(75, 149)
print(len(numericColumns[sl]))
# Out:
# 65

# %%
#numeric variables

plt.figure(figsize=(20,45))

i = 1
for variables in numericColumns[sl]:
    plt.subplot(15,5,i)
    sns.distplot(churn_filtered[variables])
    i+=1
    
plt.show()

# %% [markdown]
# #### Inference : Lot of variables are skewed towards left. Indicating that values around zero.

# %%
# change churn to numeric
churn_filtered['churn_probability'] = pd.to_numeric(churn_filtered['churn_probability'])

# %%
#Distribution for the churn probability
plt.figure(figsize=(8,4))
sns.histplot(churn_filtered['churn_probability'])
# Out:
# <Axes: xlabel='churn_probability', ylabel='Count'>

# %% [markdown]
# ### Total recharge amount comparison Good v/s Action phase

# %%
plt.figure(figsize=(12, 9))
plt.subplot(2,2,1)
sns.histplot(churn_filtered.total_rech_amt_7)
plt.subplot(2,2,2)
sns.histplot(churn_filtered.total_rech_amt_8)
# Out:
# <Axes: xlabel='total_rech_amt_8', ylabel='Count'>

# %% [markdown]
# #### Inference : Total recharge has gone down in action month as expected

# %% [markdown]
# ### Total incoming minutes of usage amount comparison Good v/s Action phase

# %%
plt.figure(figsize=(12, 9))
plt.subplot(2,2,1)
sns.histplot(churn_filtered.total_ic_mou_7)
plt.subplot(2,2,2)
sns.histplot(churn_filtered.total_ic_mou_8)
# Out:
# <Axes: xlabel='total_ic_mou_8', ylabel='Count'>

# %% [markdown]
# #### Inference : Total incoming minutes of usage has gone down in action month as expected

# %% [markdown]
# ### Total outgoing minutes of usage amount comparison Good v/s Action phase

# %%
plt.figure(figsize=(12, 9))
plt.subplot(2,2,1)
sns.histplot(churn_filtered.total_og_mou_7)
plt.subplot(2,2,2)
sns.histplot(churn_filtered.total_og_mou_8)
# Out:
# <Axes: xlabel='total_og_mou_8', ylabel='Count'>

# %% [markdown]
# #### Inference : Total outgoing minutes of usage has gone down in action month,as expected

# %% [markdown]
# ### Total incoming minutes of usage amount comparison Good v/s Action phase

# %%
# plt.subplot(2,2,1)
# sns.histplot(churn_filtered.)
# plt.subplot(2,2,2)
# sns.histplot(churn_filtered.total_ic_mou_8)

# %% [markdown]
# #### Inference : Total incoming minutes of usage has gone down in action month as expected

# %% [markdown]
# ## Bivariate EDA

# %% [markdown]
# ### Churn probability wrt Total recharge amount comparison Good v/s Action phase

# %%
plt.figure(figsize=(12, 9))
plt.subplot(2,2,1)
sns.barplot(x= churn_filtered.churn_probability, y = churn_filtered.total_rech_amt_7)
plt.subplot(2,2,2)
sns.barplot(x=churn_filtered.churn_probability, y=churn_filtered.total_rech_amt_8)
# Out:
# <Axes: xlabel='churn_probability', ylabel='total_rech_amt_8'>

# %% [markdown]
# #### Inference : Total recharge has gone down in action month for people who churned

# %% [markdown]
# ### Churn probability wrt Total incoming minutes of usage comparison Good v/s Action phase

# %%
plt.figure(figsize=(12, 9))
plt.subplot(2,2,1)
sns.barplot(x= churn_filtered.churn_probability, y = churn_filtered.total_ic_mou_7)
plt.subplot(2,2,2)
sns.barplot(x=churn_filtered.churn_probability, y=churn_filtered.total_ic_mou_8)
# Out:
# <Axes: xlabel='churn_probability', ylabel='total_ic_mou_8'>

# %% [markdown]
# #### Inference : Total incoming minutes of usage has gone down in action month for people who churned

# %% [markdown]
# ### Churn probability wrt Total outgoing minutes of usage comparison Good v/s Action phase

# %%
plt.figure(figsize=(12, 9))
plt.subplot(2,2,1)
sns.barplot(x= churn_filtered.churn_probability, y = churn_filtered.total_og_mou_7)
plt.subplot(2,2,2)
sns.barplot(x=churn_filtered.churn_probability, y=churn_filtered.total_og_mou_8)
# Out:
# <Axes: xlabel='churn_probability', ylabel='total_og_mou_8'>

# %% [markdown]
# #### Inference : Total outgoing minutes of usage has gone down in action month for people who churned

# %%
# All Categorical columns Bivariate analysis

plt.figure(figsize=(22,29))

i = 1
for variables in cat_cols:
    plt.subplot(5,4,i)
    sns.boxplot(y= variables , x= churn_filtered.churn_probability, data=churn_filtered )
    i+=1

# %%
pd.crosstab(churn_filtered.churn_probability, churn_filtered.night_pck_user_8, normalize='columns')*100
# Out:
# night_pck_user_8   -1.000000   0.000000   0.635294
# churn_probability
# 0                   85.80002  96.975235  97.046414
# 1                   14.19998   3.024765   2.953586

# %%
pd.crosstab(churn_filtered.churn_probability, churn_filtered.sachet_3g_8)
# Out:
# sachet_3g_8        0.000000  1.000000  2.000000  2.125593
# churn_probability
# 0                     17450      1146       279       402
# 1                      1684        33         3        14

# %% [markdown]
# ## 4. Model building

# %% [markdown]
# #### Feature scaling
#
# Lets also scale the features by scaling them with Standard scaler (few other alternates are min-max scaling and Z-scaling).

# %%
churn_filtered.shape
# Out:
# (21011, 140)

# %%
churn_filtered
# Out:
#          arpu_6       arpu_7       arpu_8  onnet_mou_6  onnet_mou_7  \
# 0       240.708   128.191000   101.565000        21.28         4.83
# 1       580.549   377.294000   338.286000        10.43        24.99
# 2      1130.948   905.506000   479.762000       859.53       372.71
# 3       371.974   352.069000   240.449000        93.18        38.29
# 4       390.489   350.985000   421.300000         8.58        11.48
# ...         ...          ...          ...          ...          ...
# 21006  1106.130  1311.286693  1334.631771        84.91       133.44
# 21007   196.695   298.645000   192.440000         1.05         0.00
# 21008   235.524   195.633000   129.598000        45.08        94.31
# 21009    15.760   410.924000   329.136000         0.00         7.36
# 21010   238.575   245.414000   145.062000        14.01         7.64
#
#        onnet_mou_8  offnet_mou_6  offnet_mou_7  offnet_mou_8  roam_ic_mou_6  \
# ...

# %%
# change churn to numeric
churn_filtered['churn_probability'] = pd.to_numeric(churn_filtered['churn_probability'])

# %%
# divide data into train and test
X = churn_filtered.drop("churn_probability", axis = 1)
y = churn_filtered.churn_probability
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)

# %%
# print shapes of train and test sets
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (14707, 139)
# (14707,)
# (6304, 139)
# (6304,)

# %% [markdown]
# ## PCA

# %%
# apply pca to train data
pca = Pipeline([('scaler', StandardScaler()), ('pca', PCA())])

# %%
pca.fit(X_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA())])

# %%
churn_pca = pca.fit_transform(X_train)

# %%
# extract pca model from pipeline
pca = pca.named_steps['pca']

# %%
pca.components_
# Out:
# array([[ 1.28574835e-01,  1.37407536e-01,  1.24083941e-01, ...,
#         -6.59980698e-02, -7.07128866e-02, -6.84486077e-02],
#        [ 3.70715638e-02,  4.11254614e-02,  6.79021973e-02, ...,
#          1.14335312e-01,  1.09622127e-01,  1.05161551e-01],
#        [ 9.99785433e-02,  1.41402932e-01,  1.48619677e-01, ...,
#          1.29471630e-01,  1.26996899e-01,  1.19299222e-01],
#        ...,
#        [ 6.32551971e-04, -3.33894847e-03, -4.83450353e-03, ...,
#          7.76171354e-04, -2.81952130e-03,  1.22206274e-03],
#        [ 1.51261244e-03, -3.04822725e-03, -3.11742418e-03, ...,
#          8.46222626e-04,  1.79032708e-04,  3.96730285e-04],
#        [-1.49934517e-03, -3.88656380e-05, -5.22962208e-03, ...,
#          1.91360811e-04, -1.83492512e-04,  6.63106697e-05]])

# %%
pca.explained_variance_ratio_
# Out:
# array([1.45137243e-01, 1.14555422e-01, 6.15469519e-02, 4.96738806e-02,
#        4.21284451e-02, 3.03910487e-02, 2.61377008e-02, 2.52568058e-02,
#        2.41113042e-02, 2.20412444e-02, 2.14375904e-02, 1.86630310e-02,
#        1.80793466e-02, 1.62971496e-02, 1.50578645e-02, 1.48112961e-02,
#        1.40158233e-02, 1.32310423e-02, 1.30100942e-02, 1.18675413e-02,
#        1.10592525e-02, 1.03588881e-02, 9.66850161e-03, 9.56797706e-03,
#        9.00254379e-03, 8.76186739e-03, 8.64015403e-03, 8.30847480e-03,
#        8.04619209e-03, 7.38540081e-03, 7.26325580e-03, 6.90358601e-03,
#        6.49534023e-03, 6.35143921e-03, 6.20061273e-03, 6.11168876e-03,
#        5.95100728e-03, 5.51885481e-03, 5.44477887e-03, 5.17956165e-03,
#        5.07230841e-03, 4.88625038e-03, 4.72157263e-03, 4.60908182e-03,
#        4.56886415e-03, 4.34182803e-03, 4.07211385e-03, 4.04347936e-03,
#        3.94566979e-03, 3.81754495e-03, 3.68461301e-03, 3.55128424e-03,
# ...

# %%
plt.bar(range(1,len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_)
# Out:
# <BarContainer object of 139 artists>

# %%
var_cumu = np.cumsum(pca.explained_variance_ratio_)

# %% [markdown]
# #### Making the scree plot

# %%
fig = plt.figure(figsize=[8,5])
plt.vlines(x=60, ymax=1, ymin=0, colors="r", linestyles="--")
plt.hlines(y=0.93, xmax=150, xmin=0, colors="g", linestyles="--")
plt.plot(range(1,len(var_cumu)+1), var_cumu)

# %% [markdown]
# #### Inference from Scree plot is : About 60 components are able to explain 93% of feature variance so let's consider 60 components

# %%
from sklearn.decomposition import IncrementalPCA

# %%
pca_final = IncrementalPCA(n_components = 60)

X_train_pca = pca_final.fit_transform(X_train)

# %%
print("Size of earlier dataset was :",X_train.shape)
print("Size of dataset after PCA is:", X_train_pca.shape)
# Out:
# Size of earlier dataset was : (14707, 139)
# Size of dataset after PCA is: (14707, 60)

# %%
#creating correlation matrix for the given data
corrmat = np.corrcoef(X_train_pca.transpose())

#Make a diagonal matrix with diagonal entry of Matrix corrmat
p = np.diagflat(corrmat.diagonal())

# subtract diagonal entries making all diagonals 0
corrmat_diag_zero = corrmat - p
print("max positive corr:",round(corrmat_diag_zero.max(),3), ", min negative corr: ", round(corrmat_diag_zero.min(),3))
# Out:
# max positive corr: 0.004 , min negative corr:  -0.003

# %%
X_test.fillna(X_test.mean())
# Out:
#         arpu_6   arpu_7   arpu_8  onnet_mou_6  onnet_mou_7  onnet_mou_8  \
# 17919  159.733  826.176  860.843    18.590000   140.780000       364.79
# 2113   516.000  413.000  679.000    32.540000    81.610000       110.46
# 937    867.076  709.916  291.046   287.080000   238.490000        14.83
# 4063   343.793  284.960  226.295    41.190000     9.160000         8.21
# 16725  298.005  289.972  303.795   658.560000   699.860000       995.48
# ...        ...      ...      ...          ...          ...          ...
# 19684  473.881  288.232   39.885    34.860000    71.290000         2.45
# 1007   669.121  789.687  600.059  1013.234431  1047.733766       934.53
# 11664  653.473  470.858  616.357   833.160000   545.940000       450.04
# 13422  596.601  577.490  436.927   121.240000   139.910000       117.88
# 13349  154.449   97.074  159.769     0.000000     0.000000         0.00
#
#        offnet_mou_6  offnet_mou_7  offnet_mou_8  roam_ic_mou_6  ...  \
# ...

# %% [markdown]
# #### PCA is able to handle correlation so we are good to use 60 components for better results

# %% [markdown]
# ### Model 1 : PCA and Logistic Regression

# %%
# create pipeline
PCA_VARS = 60
steps = [('scaler', StandardScaler()),
         ("pca", IncrementalPCA(n_components = PCA_VARS) ),
         ("logistic", LogisticRegression(class_weight='balanced'))
        ]
pca_logistic_pipeline = Pipeline(steps)

# %%
# fit model
pca_logistic_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('pca', IncrementalPCA(n_components=60)),
#                 ('logistic', LogisticRegression(class_weight='balanced'))])

# %%
# predict churn on test data
y_pred_train = pca_logistic_pipeline.predict(X_train)

# %%
# check score on train data
pca_logistic_pipeline.score(X_train, y_train)
# Out:
# 0.8261372135717685

# %%
# create confusion matrix
cm = confusion_matrix(y_train, y_pred_train)
print(cm)
# Out:
# [[11144  2349]
#  [  208  1006]]

# %%
# check sensitivity and specificity
sensitivity, specificity, _ = sensitivity_specificity_support(y_train, y_pred_train, average='binary')
print("Sensitivity: \t", round(sensitivity, 2), "\n", "Specificity: \t", round(specificity, 2), sep='')
# Out:
# Sensitivity: 	0.83
# Specificity: 	0.83

# %%
# check area under curve
y_pred_prob = pca_logistic_pipeline.predict_proba(X_train)[:, 1]
print("AUC:    \t", round(roc_auc_score(y_train, y_pred_prob),2))
# Out:
# AUC:    	 0.9

# %%
print(metrics.accuracy_score(y_train, y_pred_train))
# Out:
# 0.8261372135717685

# %% [markdown]
# ### Evaluate on test data

# %%
# predict churn on test data
y_pred = pca_logistic_pipeline.predict(X_test)

# %%
pca_logistic_pipeline.score(X_test, y_test)
# Out:
# 0.8239213197969543

# %%
# create confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[4761 1023]
#  [  87  433]]

# %%
# check sensitivity and specificity
sensitivity, specificity, _ = sensitivity_specificity_support(y_test, y_pred, average='binary')
print("Sensitivity: \t", round(sensitivity, 2), "\n", "Specificity: \t", round(specificity, 2), sep='')
# Out:
# Sensitivity: 	0.83
# Specificity: 	0.82

# %%
# check area under curve
y_pred_prob = pca_logistic_pipeline.predict_proba(X_test)[:, 1]
print("AUC:    \t", round(roc_auc_score(y_test, y_pred_prob),2))
# Out:
# AUC:    	 0.9

# %%
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.8239213197969543

# %% [markdown]
# ### Model 2 : PCA and Logistic Regression - Hyperparameter tuning

# %%
# class imbalance
y_train.value_counts()/y_train.shape
# Out:
# 0    0.917454
# 1    0.082546
# Name: churn_probability, dtype: float64

# %%
# PCA
pca = IncrementalPCA(n_components = PCA_VARS)

# logistic regression - the class weight is used to handle class imbalance - it adjusts the cost function
logistic = LogisticRegression(class_weight={0:0.1, 1: 0.9})

# create pipeline
steps = [("scaler", StandardScaler()),
         ("pca", pca),
         ("logistic", logistic)
        ]

# compile pipeline
pca_logistic = Pipeline(steps)

# %%
# hyperparameter space
params = {'pca__n_components': [60, 80], 'logistic__C': [0.1, 0.5, 1, 2, 3, 4, 5, 10], 'logistic__penalty': ['l1', 'l2']}

# create 5 folds
folds = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 4)

# %% [markdown]
# - Using recall as scoring strategy as we want to reatin the customers, who have the possiblity to churn. Predicting few not churn customers as churn customers should not be a problem. Hence, considering sensitivity/recall score as more important.

# %%
# create gridsearch object
pca_logistic_model = GridSearchCV(estimator=pca_logistic, cv=folds, param_grid=params, scoring='recall', n_jobs=-1, verbose=1)

# %%
# fit model
pca_logistic_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('pca', IncrementalPCA(n_components=60)),
#                                        ('logistic',
#                                         LogisticRegression(class_weight={0: 0.1,
#                                                                          1: 0.9}))]),
#              n_jobs=-1,
#              param_grid={'logistic__C': [0.1, 0.5, 1, 2, 3, 4, 5, 10],
#                          'logistic__penalty': ['l1', 'l2'],
#                          'pca__n_components': [60, 80]},
#              scoring='recall', verbose=1)

# %%
# cross validation results
pd.DataFrame(pca_logistic_model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.324754      0.010404         0.000000        0.000000
# 1        0.310950      0.016920         0.000000        0.000000
# 2        0.352204      0.007862         0.009372        0.002578
# 3        0.375192      0.022763         0.008623        0.002816
# 4        0.308448      0.009004         0.000000        0.000000
# 5        0.362064      0.015721         0.000000        0.000000
# 6        0.407858      0.037076         0.009356        0.003342
# 7        0.459035      0.021611         0.012269        0.005666
# 8        0.339481      0.022998         0.000000        0.000000
# 9        0.331346      0.012639         0.000000        0.000000
# 10       0.376366      0.037025         0.007656        0.002415
# 11       0.380936      0.023123         0.006929        0.000976
# 12       0.302770      0.013911         0.000000        0.000000
# ...

# %%
# print best hyperparameters
print("Best AUC: ", pca_logistic_model.best_score_)
print("Best hyperparameters: ", pca_logistic_model.best_params_)
# Out:
# Best AUC:  0.8006529945923886
# Best hyperparameters:  {'logistic__C': 2, 'logistic__penalty': 'l2', 'pca__n_components': 80}

# %%
# predict churn on test data
y_train_pred = pca_logistic_model.predict(X_train)

# %%
# create onfusion matrix
cm = confusion_matrix(y_train, y_train_pred)
print(cm)
# Out:
# [[11495  1998]
#  [  232   982]]

# %%
# check sensitivity and specificity
sensitivity, specificity, _ = sensitivity_specificity_support(y_train, y_train_pred, average='binary')
print("Sensitivity: \t", round(sensitivity, 2), "\n", "Specificity: \t", round(specificity, 2), sep='')

# check area under curve
y_pred_prob = pca_logistic_model.predict_proba(X_train)[:, 1]
print("AUC:    \t", round(roc_auc_score(y_train, y_pred_prob),2))
# Out:
# Sensitivity: 	0.81
# Specificity: 	0.85
# AUC:    	 0.9

# %%
print(metrics.accuracy_score(y_train, y_train_pred))
# Out:
# 0.8483715237641939

# %%
pca_logistic_model.score(X_train, y_train)
# Out:
# 0.8088962108731467

# %% [markdown]
# ### Evaluate on the test set

# %%
# predict churn on test data
y_pred = pca_logistic_model.predict(X_test)

# %%
# create onfusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[4917  867]
#  [  90  430]]

# %%
# check sensitivity and specificity
sensitivity, specificity, _ = sensitivity_specificity_support(y_test, y_pred, average='binary')
print("Sensitivity: \t", round(sensitivity, 2), "\n", "Specificity: \t", round(specificity, 2), sep='')

# check area under curve
y_pred_prob = pca_logistic_model.predict_proba(X_test)[:, 1]
print("AUC:    \t", round(roc_auc_score(y_test, y_pred_prob),2))
# Out:
# Sensitivity: 	0.83
# Specificity: 	0.85
# AUC:    	 0.9

# %%
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.8481916243654822

# %%
pca_logistic_model.score(X_test, y_test)
# Out:
# 0.8269230769230769

# %% [markdown]
# ## Model 3 :  Random Forest

# %%
from sklearn.metrics import roc_curve

# %%
# Running the random forest with default parameters
rfc = RandomForestClassifier(class_weight = 'balanced',random_state=100,n_jobs = -1)

# fit
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=100)

# %%
rfc_disp = RocCurveDisplay.from_estimator(rfc, X_train, y_train)

# %%
# Making Predictions
y_pred_train = rfc.predict(X_train)

# %%
logit_roc_auc = metrics.roc_auc_score(y_train, y_pred_train )
fpr, tpr, thresholds = metrics.roc_curve(y_train, y_pred_train )
plt.figure()
plt.plot(fpr, tpr, label='RFC Default (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

print("Area under curve is:", round(metrics.roc_auc_score(y_train, y_pred_train),2))
print("Recall for our model is:" , round(metrics.recall_score(y_train, y_pred_train),2))
print("Accuracy on test set is:" , round(metrics.accuracy_score(y_train, y_pred_train),2))
print("Confusion matrix for our model is:" , metrics.confusion_matrix(y_train, y_pred_train))
# Out:
# Area under curve is: 1.0
# Recall for our model is: 1.0
# Accuracy on test set is: 1.0
# Confusion matrix for our model is: [[13493     0]
#  [    1  1213]]

# %%
# Printing confusion matrix
cm = confusion_matrix(y_train,y_pred_train)
print(cm)
# Out:
# [[13493     0]
#  [    1  1213]]

# %%
speci = round((cm[0,0]/(cm[0,0]+cm[0,1])),2)
sensi = round((cm[1,1]/(cm[1,0]+cm[1,1])),2)

print('The specificity is:',speci)
print('The sensitivity is:',sensi)
print('The accuracy is:', accuracy_score(y_train,y_pred_train))

rfc.score(X_train, y_train)
# Out:
# The specificity is: 1.0
# The sensitivity is: 1.0
# The accuracy is: 0.9999320051676073
# 0.9999320051676073

# %% [markdown]
# ### Evaluation on the test set

# %%
# Making Predictions
y_pred_default = rfc.predict(X_test)

# %%
logit_roc_auc = metrics.roc_auc_score(y_test, y_pred_default )
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_default )
plt.figure()
plt.plot(fpr, tpr, label='RFC Default (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

print("Area under curve is:", round(metrics.roc_auc_score(y_test, y_pred_default),2))
print("Recall for our model is:" , round(metrics.recall_score(y_test, y_pred_default),2))
print("Accuracy on test set is:" , round(metrics.accuracy_score(y_test, y_pred_default),2))
print("Confusion matrix for our model is:" , metrics.confusion_matrix(y_test, y_pred_default))
# Out:
# Area under curve is: 0.72
# Recall for our model is: 0.45
# Accuracy on test set is: 0.95
# Confusion matrix for our model is: [[5727   57]
#  [ 288  232]]

# %%
# Printing confusion matrix
cm = confusion_matrix(y_test,y_pred_default)
print(cm)
# Out:
# [[5727   57]
#  [ 288  232]]

# %%
speci = round((cm[0,0]/(cm[0,0]+cm[0,1])),2)
sensi = round((cm[1,1]/(cm[1,0]+cm[1,1])),2)

print('The specificity is:',speci)
print('The sensitivity is:',sensi)
print('The accuracy is:', accuracy_score(y_test,y_pred_default))

rfc.score(X_test, y_test)
# Out:
# The specificity is: 0.99
# The sensitivity is: 0.45
# The accuracy is: 0.9452728426395939
# 0.9452728426395939

# %% [markdown]
# ##### Sensitivity is very low for test set. Let's tune parameters

# %% [markdown]
# ## Model 4 : Random forest - Hyperparameter Tuning

# %% [markdown]
# ##### Tuning parameters one by one as a whole it is taking lot of time

# %%
# max_depth parameters to build the model on
parameters = {'max_depth': range(5, 15, 30)}

# number of folds
n_folds = 5

# instantiate the model
rf_ht = RandomForestClassifier(class_weight = 'balanced',random_state=0)


# fit tree on training data
rf_ht = GridSearchCV(rf_ht, parameters, return_train_score=True,cv=n_folds, n_jobs=-1,
                   scoring="recall",verbose = 1)

# %%
# %%time
rf_ht.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# CPU times: user 2.37 s, sys: 16.3 ms, total: 2.38 s
# Wall time: 4.72 s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=0),
#              n_jobs=-1, param_grid={'max_depth': range(5, 15, 30)},
#              return_train_score=True, scoring='recall', verbose=1)

# %%
print(rf_ht.best_score_)
print(rf_ht.best_params_)
# Out:
# 0.724065571540319
# {'max_depth': 5}

# %%
rf_ht_1 = rf_ht.best_estimator_
rf_ht_1
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=5, random_state=0)

# %%
rfc_disp = RocCurveDisplay.from_estimator(rf_ht_1, X_train, y_train)

# %% [markdown]
# ##### Tune n_estimators

# %%
# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'n_estimators': [10,25,50,75,100]}

# instantiate the model (note we are specifying a max_depth)
rf = RandomForestClassifier(random_state = 42,class_weight='balanced')

# fit tree on training data
rf = GridSearchCV(rf, parameters,cv=n_folds, verbose=1,scoring="recall",return_train_score = True, 
                  n_jobs=-1)

# %%
# %%time
rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# CPU times: user 3.73 s, sys: 53.2 ms, total: 3.78 s
# Wall time: 16.8 s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              n_jobs=-1, param_grid={'n_estimators': [10, 25, 50, 75, 100]},
#              return_train_score=True, scoring='recall', verbose=1)

# %%
print(rf.best_score_)
print(rf.best_params_)
# Out:
# 0.43825119885725944
# {'n_estimators': 75}

# %% [markdown]
# ##### Tune min_samples_leaf

# %%
# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'min_samples_leaf': [5,10,20,50,100,200]}

# instantiate the model (note we are specifying a max_depth)
rf = RandomForestClassifier(random_state = 42,class_weight='balanced')

# fit tree on training data
rf = GridSearchCV(rf, parameters,cv=n_folds, verbose=1,scoring="recall",return_train_score = True, 
                  n_jobs=-1)

# %%
# %%time
rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# CPU times: user 2.99 s, sys: 59.5 ms, total: 3.05 s
# Wall time: 24.6 s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'min_samples_leaf': [5, 10, 20, 50, 100, 200]},
#              return_train_score=True, scoring='recall', verbose=1)

# %%
print(rf.best_score_)
print(rf.best_params_)
# Out:
# 0.7578308335884094
# {'min_samples_leaf': 200}

# %% [markdown]
# #### Tuning max_features

# %%
# specify number of folds for k-fold CV
n_folds = 3

# parameters to build the model on
parameters = {'max_features': [25,50,75,100]}

# instantiate the model (note we are specifying a max_depth)
rf = RandomForestClassifier(max_depth=5, class_weight = 'balanced',random_state=100)

# fit tree on training data
rf = GridSearchCV(rf, parameters, n_jobs  = -1,cv=n_folds, verbose = 1,
                   scoring="recall",return_train_score=True)

# %%
# %%time
rf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# CPU times: user 9.01 s, sys: 44.7 ms, total: 9.05 s
# Wall time: 35 s
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               max_depth=5, random_state=100),
#              n_jobs=-1, param_grid={'max_features': [25, 50, 75, 100]},
#              return_train_score=True, scoring='recall', verbose=1)

# %%
print(rf.best_score_)
print(rf.best_params_)
# Out:
# 0.7520698366132909
# {'max_features': 50}

# %% [markdown]
# #### Tuning for optimal hyperparmaeter

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'max_depth': [8,8,10],
    'min_samples_split': [170,190,200], 'min_samples_leaf': [120,130,140] }

# Create a based model
rf = RandomForestClassifier(class_weight = 'balanced',random_state=100)

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, scoring='recall',
                          cv = 3, n_jobs = -1,verbose = 1,return_train_score=True)

# %%
# Fit the grid search to the data
grid_search.fit(X_train, y_train)
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# 0.766057531679094
# {'max_depth': 8, 'min_samples_leaf': 140, 'min_samples_split': 170}

# %%
# Let's use these optimal values to fit for final model

# %%
rfc_final = RandomForestClassifier(bootstrap=True,random_state=100,
                             max_depth=grid_search.best_params_['max_depth'],
                             min_samples_split=grid_search.best_params_['min_samples_split'],
                             max_features = 100, min_samples_leaf = 100,
                              class_weight='balanced')

# %%
# fit
rfc_final.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=8, max_features=100,
#                        min_samples_leaf=100, min_samples_split=170,
#                        random_state=100)

# %%
# Making Predictions
y_pred_train = rfc_final.predict(X_train)

# %%
logit_roc_auc = metrics.roc_auc_score(y_train, y_pred_train )
fpr, tpr, thresholds = metrics.roc_curve(y_train, y_pred_train )
plt.figure()
plt.plot(fpr, tpr, label='RFC Default (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

print("Area under curve is:", round(metrics.roc_auc_score(y_train, y_pred_train),2))
print("Recall for our model is:" , round(metrics.recall_score(y_train, y_pred_train),2))
print("Accuracy on test set is:" , round(metrics.accuracy_score(y_train, y_pred_train),2))
print("Confusion matrix for our model is:" , metrics.confusion_matrix(y_train, y_pred_train))
# Out:
# Area under curve is: 0.87
# Recall for our model is: 0.85
# Accuracy on test set is: 0.9
# Confusion matrix for our model is: [[12178  1315]
#  [  187  1027]]

# %%
# Printing confusion matrix
cm = confusion_matrix(y_train,y_pred_train)
print(cm)
# Out:
# [[12178  1315]
#  [  187  1027]]

# %%
speci = round((cm[0,0]/(cm[0,0]+cm[0,1])),2)
sensi = round((cm[1,1]/(cm[1,0]+cm[1,1])),2)

print('The specificity is:',speci)
print('The sensitivity is:',sensi)
print('The accuracy is:', accuracy_score(y_train,y_pred_train))

rfc_final.score(X_train, y_train)
# Out:
# The specificity is: 0.9
# The sensitivity is: 0.85
# The accuracy is: 0.8978717617461073
# 0.8978717617461073

# %% [markdown]
# #### Evaluation on the test set

# %%
predictions = rfc_final.predict(X_test)

# %%
logit_roc_auc = metrics.roc_auc_score(y_test, predictions )
fpr, tpr, thresholds = metrics.roc_curve(y_test, predictions )
plt.figure()
plt.plot(fpr, tpr, label='RFC Default (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

print("Area under curve is:", round(metrics.roc_auc_score(y_test, predictions),2))
print("Recall for our model is:" , round(metrics.recall_score(y_test, predictions),2))
print("Accuracy on test set is:" , round(metrics.accuracy_score(y_test, predictions),2))
print("Confusion matrix for our model is:" , metrics.confusion_matrix(y_test, predictions))
# Out:
# Area under curve is: 0.86
# Recall for our model is: 0.81
# Accuracy on test set is: 0.89
# Confusion matrix for our model is: [[5188  596]
#  [  97  423]]

# %%
# confusion matrix
cm = confusion_matrix(y_test,predictions)
print(cm)
# Out:
# [[5188  596]
#  [  97  423]]

# %%
speci = cm[0,0]/(cm[0,0]+cm[0,1])
sensi = cm[1,1]/(cm[1,0]+cm[1,1])

print('The specificity is:',speci)
print('The sensitivity is:',sensi)
# Out:
# The specificity is: 0.896957123098202
# The sensitivity is: 0.8134615384615385

# %%
rfc_final.score(X_test,y_test)
# Out:
# 0.8900697969543148

# %%
print("Accuracy on test set is:" , round(metrics.accuracy_score(y_test, predictions),2))
# Out:
# Accuracy on test set is: 0.89

# %% [markdown]
# ## 5. Model Selection

# %% [markdown]
# #### Logistic Regression with PCA

# %% [markdown]
# - Sensitivity: 0.83
# - Specificity: 0.82
# - Area Under the Curve:    0.9
# - Accuracy on test set is : 0.82
# - Model Score 0.82

# %% [markdown]
# #### Logistic Regression with PCA ( with Hyperparameter tuning)

# %% [markdown]
# - Sensitivity: 0.83
# - Specificity: 0.85
# - Area Under the Curve:   0.9
# - Accuracy on test set is : 0.85
# - Model Score 0.85

# %% [markdown]
# #### Random Forest (with HypreParameters)

# %% [markdown]
# - Sensitivity: 0.81
# - Specificity: 0.89
# - Area Under the Curve: 0.86
# - Accuracy on test set is : 0.89
# - Model Score 0.89
# - Confusion matrix for our model is:
# [[5194  590]
#  [  99  421]]

# %% [markdown]
# ### Inference :  Logistic Regression with PCA ( with Hyperparameter tuning) has good Sensitivity as well as overall better result

# %% [markdown]
# ### 6. Chose important predictor variables from Final Random Forest Model

# %%
importance = rfc_final.feature_importances_

# %%
features = churn_filtered.drop('churn_probability', axis=1).columns

# %%
# create dataframe
feature_importance = pd.DataFrame({'variables': features, 'importance_percentage': importance*100})
feature_importance = feature_importance[['variables', 'importance_percentage']]

# sort features
feature_importance = feature_importance.sort_values('importance_percentage', ascending=False).reset_index(drop=True)
print("Sum of importance=", feature_importance.importance_percentage.sum())
feature_importance
# Out:
# Sum of importance= 100.0
#               variables  importance_percentage
# 0          loc_ic_mou_8              38.551139
# 1        total_ic_mou_8              12.027814
# 2      loc_ic_t2m_mou_8               7.990798
# 3         roam_og_mou_8               6.493236
# 4    last_day_rch_amt_8               4.878296
# ..                  ...                    ...
# 134         og_others_7               0.000000
# 135         og_others_8               0.000000
# 136    std_og_t2f_mou_8               0.000000
# 137        monthly_2g_8               0.000000
# 138    std_og_t2f_mou_7               0.000000
#
# [139 rows x 2 columns]

# %%
feature_importance.head(50)
# Out:
#              variables  importance_percentage
# 0         loc_ic_mou_8              38.551139
# 1       total_ic_mou_8              12.027814
# 2     loc_ic_t2m_mou_8               7.990798
# 3        roam_og_mou_8               6.493236
# 4   last_day_rch_amt_8               4.878296
# 5   av_rech_amt_data_8               4.783043
# 6         std_og_mou_7               2.661798
# 7            fb_user_8               2.619262
# 8     total_rech_amt_8               2.316585
# 9        roam_ic_mou_8               1.746606
# 10         vol_2g_mb_8               0.831250
# 11              arpu_7               0.797215
# 12      total_og_mou_8               0.679678
# 13    total_rech_num_7               0.622491
# 14              arpu_8               0.510843
# 15        loc_og_mou_8               0.389558
# 16      total_ic_mou_7               0.388488
# 17     max_rech_data_8               0.377660
# 18       roam_ic_mou_7               0.374674
# ...

# %%
# extract top 'n' features
top_n = 30
top_features = feature_importance.variables[0:top_n]

# %%
top_features
# Out:
# 0           loc_ic_mou_8
# 1         total_ic_mou_8
# 2       loc_ic_t2m_mou_8
# 3          roam_og_mou_8
# 4     last_day_rch_amt_8
# 5     av_rech_amt_data_8
# 6           std_og_mou_7
# 7              fb_user_8
# 8       total_rech_amt_8
# 9          roam_ic_mou_8
# 10           vol_2g_mb_8
# 11                arpu_7
# 12        total_og_mou_8
# 13      total_rech_num_7
# 14                arpu_8
# 15          loc_og_mou_8
# 16        total_ic_mou_7
# 17       max_rech_data_8
# 18         roam_ic_mou_7
# 19      total_rech_num_8
# 20          offnet_mou_8
# 21      loc_ic_t2t_mou_8
# 22          std_og_mou_6
# 23         roam_og_mou_7
# 24          loc_ic_mou_7
# 25          loc_ic_mou_6
# 26      total_rech_amt_7
# 27      total_rech_amt_6
# 28      loc_ic_t2m_mou_7
# 29        max_rech_amt_8
# Name: variables, dtype: object

# %%
# plot feature correlation
import seaborn as sns
plt.rcParams["figure.figsize"] =(10,10)
mycmap = sns.diverging_palette(199, 359, s=99, center="light", as_cmap=True)
sns.heatmap(data=X_train[top_features].corr(), center=0.0, cmap=mycmap)
# Out:
# <Axes: >

# %%
X_train.shape
X_test.shape
# Out:
# (6304, 139)

# %%
X_train_top_features = X_train[top_features]
X_test_top_features = X_test[top_features]

# %%
X_train_top_features.shape
y_train.shape
# Out:
# (14707,)

# %%
X_test_top_features.shape
y_test.shape
# Out:
# (6304,)

# %%
# logistic regression
steps = [('scaler', StandardScaler()),
         ("logistic", LogisticRegression(class_weight={0:0.1, 1:0.9}))
        ]

# compile pipeline
logistic = Pipeline(steps)

# hyperparameter space
params = {'logistic__C': [0.1, 0.5, 1, 2, 3, 4, 5, 10], 'logistic__penalty': ['l1', 'l2']}

# create 5 folds
folds = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 4)

# create gridsearch object
logistic_model_final = GridSearchCV(estimator=logistic, cv=folds, param_grid=params, scoring='recall', n_jobs=-1, verbose=1)

# %%
# fit model
logistic_model_final.fit(X_train_top_features, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('logistic',
#                                         LogisticRegression(class_weight={0: 0.1,
#                                                                          1: 0.9}))]),
#              n_jobs=-1,
#              param_grid={'logistic__C': [0.1, 0.5, 1, 2, 3, 4, 5, 10],
#                          'logistic__penalty': ['l1', 'l2']},
#              scoring='recall', verbose=1)

# %%
# print best hyperparameters
print("Best AUC: ", logistic_model_final.best_score_)
print("Best hyperparameters: ", logistic_model_final.best_params_)
# Out:
# Best AUC:  0.7973438084549195
# Best hyperparameters:  {'logistic__C': 2, 'logistic__penalty': 'l2'}

# %%
# predict churn on test data
y_pred = logistic_model_final.predict(X_test_top_features)

# create onfusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# check sensitivity and specificity
sensitivity, specificity, _ = sensitivity_specificity_support(y_test, y_pred, average='binary')
print("Sensitivity: \t", round(sensitivity, 2), "\n", "Specificity: \t", round(specificity, 2), sep='')

# check area under curve
y_pred_prob = logistic_model_final.predict_proba(X_test_top_features)[:, 1]
print("ROC:    \t", round(roc_auc_score(y_test, y_pred_prob),2))
# Out:
# [[4933  851]
#  [ 108  412]]
# Sensitivity: 	0.79
# Specificity: 	0.85
# ROC:    	 0.89

# %%
logistic_model_final.score(X_test_top_features,y_test)
# Out:
# 0.7923076923076923

# %%
print("Accuracy on test set is:" , round(metrics.accuracy_score(y_test, y_pred),2))
# Out:
# Accuracy on test set is: 0.85

# %% [markdown]
# ### Extract the intercept and the coefficients from the model

# %%
logistic_model = logistic_model_final.best_estimator_.named_steps['logistic']

# %%
# intercept
intercept_df = pd.DataFrame(logistic_model.intercept_.reshape((1,1)), columns = ['intercept'])

# %%
# coefficients
coefficients = logistic_model.coef_.reshape((10, 3)).tolist()
coefficients = [val for sublist in coefficients for val in sublist]
coefficients = [round(coefficient, 3) for coefficient in coefficients]

logistic_features = list(X_train_top_features.columns)
coefficients_df = pd.DataFrame(logistic_model.coef_, columns=logistic_features)

# %%
# concatenate dataframes
coefficients = pd.concat([intercept_df, coefficients_df], axis=1)
coefficients
# Out:
#    intercept  loc_ic_mou_8  total_ic_mou_8  loc_ic_t2m_mou_8  roam_og_mou_8  \
# 0   -1.61136     -0.700353        -0.76535         -0.167824       0.272187
#
#    last_day_rch_amt_8  av_rech_amt_data_8  std_og_mou_7  fb_user_8  \
# 0           -0.530253           -0.380809      0.037953  -0.343809
#
#    total_rech_amt_8  ...  offnet_mou_8  loc_ic_t2t_mou_8  std_og_mou_6  \
# 0          0.218183  ...     -0.179842          0.102252      0.039713
#
#    roam_og_mou_7  loc_ic_mou_7  loc_ic_mou_6  total_rech_amt_7  \
# 0      -0.075164     -0.175034      0.134066          0.062167
#
#    total_rech_amt_6  loc_ic_t2m_mou_7  max_rech_amt_8
# 0          0.215723          0.058634       -0.152526
#
# [1 rows x 31 columns]

# %%
print(coefficients.transpose())
# Out:
#                            0
# intercept          -1.611360
# loc_ic_mou_8       -0.700353
# total_ic_mou_8     -0.765350
# loc_ic_t2m_mou_8   -0.167824
# roam_og_mou_8       0.272187
# last_day_rch_amt_8 -0.530253
# av_rech_amt_data_8 -0.380809
# std_og_mou_7        0.037953
# fb_user_8          -0.343809
# total_rech_amt_8    0.218183
# roam_ic_mou_8      -0.125851
# vol_2g_mb_8        -0.282702
# arpu_7              0.208396
# total_og_mou_8     -0.277176
# total_rech_num_7    0.165940
# arpu_8             -0.012815
# loc_og_mou_8       -0.312232
# total_ic_mou_7      0.433480
# max_rech_data_8     0.159161
# roam_ic_mou_7       0.162362
# total_rech_num_8   -0.746273
# offnet_mou_8       -0.179842
# loc_ic_t2t_mou_8    0.102252
# std_og_mou_6        0.039713
# roam_og_mou_7      -0.075164
# loc_ic_mou_7       -0.175034
# loc_ic_mou_6        0.134066
# total_rech_amt_7    0.062167
# total_rech_amt_6    0.215723
# loc_ic_t2m_mou_7    0.058634
# max_rech_amt_8     -0.152526

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. High-value customer will churn or not, in near future
# 2. Identifies customers who'll definitely churn with more accuracy as compared to the ones who'll not churn.
# - In this case if we consider recall instead of accuracy we will be able to predict definite churn cases

# %% [markdown]
# #### Logistic Regression with PCA ( with Hyperparameter tuning)

# %% [markdown]
#     - Sensitivity: 0.83
#     - Specificity: 0.85
#     - Area Under the Curve:   0.9
#     - Accuracy on test set is : 0.85
#     - Model Score 0.83
#
# - This model is built considering
#     - the behavioural features of high-value customers
#     - Recall as scoring criteria
# - Hence it can be used in predicting if high value cusotmers will churn or not as well as Identifies customers who'll definitely churn with more accuracy as compared to the ones who'll not churn.

# %% [markdown]
# #### Random Forest (with HyperParameters tuning)

# %% [markdown]
#     - Sensitivity: 0.81
#     - Specificity: 0.89
#     - Area Under the Curve: 0.86
#     - Accuracy on test set is : 0.89
#     - Model Score 0.89
#
# - Although it has slightly low sensitivity, it is able to handle the class imbalance between churn and non-churn cases. Hence the over all score and accuracy on test is better using this model.
# - Random forest also takes slightly complex computation hence consumes more time.

# %% [markdown]
# 3. Important variables that are strong predictors of churn. These variables may also indicate why customers choose to switch to other networks.

# %% [markdown]
# - loc_ic_mou_8    =   -0.700353
# - total_ic_mou_8   =  -0.765350
# - last_day_rch_amt_8 = -0.530253
# - total_rech_num_8  = -0.746273
# - total_ic_mou_7    =  0.433480
# - roam_og_mou_8   =    0.272187
# - av_rech_amt_data_8 = -0.380809
# - loc_og_mou_8   =    -0.312232
# - fb_user_8      =    -0.343809

# %% [markdown]
# - Most of important predictors are from Action month (August). Hence we can say there will be clear indications with respect to these factors from users prior to the churn month
# - Indicators also suggest bad network service since the minutes of usage for incoming and outgoing is affected. Hence the company can take actions at high churn areas.
# - Decrease in recharge amount and then the customer churns - this pattern might be because the competative prices in market so company can think about mathcing the competition.
# - This also suggests that company should keep up with customer behaviour/needs like data packs/roaming packs and provide better service than market.

# %% [markdown]
# 4. Recommend strategies to manage customer churn based on your observations

# %% [markdown]
# Based on important predictors and variable analysis the following starategies could be applied
# - Roll out offers to customers who have with lower 'total incoming or out going minutes' compared to previous month.
# - Similarly customers who have with lower 'total recharge amount' compared to previous month can also be given competitive recharge offers.
# - Another set of customers to target are the ones with lower average data recharge amount, they can be given special data offers.
# - Last day recharge amount is one of the important predictors, hence the company could roll out offers around customer recharge date.
# - Roaming offers can be given to customers using romaing offers if there is reduction in outgoing mou
# - FB data pack offers can be rolled out to customers who often recharge fb pack
